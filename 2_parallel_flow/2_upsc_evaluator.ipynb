# %%
import operator
from typing import Annotated, TypedDict

from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import END, START, StateGraph
from pydantic import BaseModel, Field

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description="Detailed feedback for the essay")
    score: int = Field(description="Score out of 10", ge=0, le=10)


structured_model = model.with_structured_output(schema=EvaluationSchema)

# %%
class UPSCState(TypedDict):
    essay: str
    clarity_feedback: str
    analysis_feedback: str
    language_feedback: str

    individual_scores: Annotated[list[int], operator.add]

    overall_feedback: str
    average_score: float

# %%
def evaluate_clarity(state: UPSCState) -> UPSCState:
    prompt = f"Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10. Essay: \n {state['essay']}"
    result = structured_model.invoke(prompt)

    return {"clarity_feedback": result.feedback, "individual_scores": [result.score]}


def evaluate_analysis(state: UPSCState) -> UPSCState:
    prompt = f"Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10. Essay: \n {state['essay']}"
    result = structured_model.invoke(prompt)

    return {"analysis_feedback": result.feedback, "individual_scores": [result.score]}


def evaluate_language(state: UPSCState) -> UPSCState:
    prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10. Essay: \n {state['essay']}"
    result = structured_model.invoke(prompt)

    return {"language_feedback": result.feedback, "individual_scores": [result.score]}


def final_evaluation(state: UPSCState) -> UPSCState:
    prompt = f"""
    Based on the following feedbacks create a summarized feedback \n 
    clarity of thought feedback -  {state['clarity_feedback']} \n 
    depth of analysis feedback -  {state['analysis_feedback']} \n 
    language quality feedback -  {state['language_feedback']}
    """
    overall_feedback = model.invoke(prompt).content

    avg_score = sum(state["individual_scores"]) / len(state["individual_scores"])

    return {"overall_feedback": overall_feedback, "average_score": avg_score}

# %%
graph = StateGraph(UPSCState)


graph.add_node("evaluate_clarity", evaluate_clarity)
graph.add_node("evaluate_analysis", evaluate_analysis)
graph.add_node("evaluate_language", evaluate_language)
graph.add_node("final_evaluation", final_evaluation)


graph.add_edge(START, "evaluate_clarity")
graph.add_edge(START, "evaluate_analysis")
graph.add_edge(START, "evaluate_language")

graph.add_edge("evaluate_clarity", "final_evaluation")
graph.add_edge("evaluate_analysis", "final_evaluation")
graph.add_edge("evaluate_language", "final_evaluation")

graph.add_edge("final_evaluation", END)


workflow = graph.compile()

# %%
workflow

# %%
essay1 = """
India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.
"""

essay2 = """
India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".
"""

# %%
initail_state1 = {
    "essay": essay1,
}

final_state1 = workflow.invoke(initail_state1)
final_state1
# Out:
# {'essay': "\nIndia in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.\n",
#  'clarity_feedback': "The essay demonstrates a good understanding of India's position in the age of AI. It clearly outlines both the opportunities and challenges, citing relevant strengths like skilled workforce and government initiatives, as well as significant hurdles such as the digital divide and data privacy concerns. The structure is logical, moving from potential to challenges and then to recommendations. The language is accessible, and the argument is well-supported with examples. The conclusion effectively summarizes the key points and emphasizes the need for a human-centered approach to AI development. To improve further, the essay could benefit from more specific data or case studies to quantify the impact of AI or the scale of the challenges. For instance, providing statistics on AI adoption in specific sectors or the projected job displacement figures would strengthen the arguments.",
#  'analysis_feedback': "The essay provides a good overview of India's potential in the AI age, highlighting its strengths such as a large pool of engineers and government initiatives like 'AI for All'. It effectively touches upon key application areas like agriculture and healthcare, and also acknowledges significant challenges like the digital divide, job displacement, and data privacy concerns. The analysis could be deepened by providing more specific examples of AI implementation and their impact, as well as a more detailed discussion on the ethical considerations and regulatory frameworks. The essay could also benefit from a stronger critical perspective on the effectiveness of current government strategies and a more in-depth exploration of international collaboration models. Overall, it's a well-structured piece that identifies the core issues but could offer more nuanced analysis and concrete evidence.",
#  'language_feedback': "The essay provides a well-structured and comprehensive overview of India's position in the age of AI. The language is clear, concise, and demonstrates a good command of vocabulary. The arguments are logical and well-supported with examples, covering both the opportunities and challenges associated with AI adoption in India. The essay effectively highlights India's strengths, potential applications, and the critical issues of the digital divide, job displacement, and data privacy. The conclusion summarizes the main points effectively and offers a forward-looking perspective. Overall, the writing is persuasive and insightful.",
#  'individual_scores': [7, 8, 9],
#  'overall_feedback': "Here's a summarized feedback based on the provided comments:\n\n**Overall Summary:**\n\nThe essay offers a **well-structured and clear overview** of India's position in the age of AI, effectively outlining both its significant opportunities and challenges. The writing is **persuasive, insightful, and uses accessible language** with a good command of vocabulary. The essay demonstrates a **good understanding** of the topic, logically presenting arguments supported by relevant examples.\n\n**Key Strengths Identified:**\n\n*   **Clear Structure and Logical Flow:** The essay moves effectively from potential to challenges and recommendations.\n*   **Identification of Key Issues:** It accurately highlights strengths (skilled workforce, government initiatives) and challenges (digital divide, data privacy, job displacement).\n*   **Good Understanding and Overview:** The essay provides a solid grasp of India's AI landscape.\n*   **Accessible and Persuasive Language:** The writing is clear, concise, and well-supported.\n\n**Areas for Improvement:**\n\n*   **Deeper Analysis and Specific Evidence:** The analysis could be strengthened by providing more **specific data, statistics, or case studies** to quantify the impact of AI and the scale of challenges.\n*   **More Nuanced Discussion:** A more in-depth exploration of **ethical considerations, regulatory frameworks, the effectiveness of current government strategies, and international collaboration models** would enhance the analysis.\n*   **Concrete Examples:** While examples are used, more detailed and specific instances of AI implementation and their outcomes would be beneficial.",
#  'average_score': 8.0}

# %%
initail_state2 = {
    "essay": essay2,
}

final_state2 = workflow.invoke(initail_state2)
final_state2
# Out:
# {'essay': '\nIndia and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".\n',
#  'clarity_feedback': 'The essay demonstrates a basic understanding of Artificial Intelligence and its potential impact on India. The author correctly identifies strengths such as a large pool of technical talent and government initiatives. They also touch upon key challenges like the digital divide, job displacement, and data privacy concerns. However, the clarity of thought is hampered by simplistic language, repetitive phrasing (e.g., "AI thing", "big big data"), and a lack of structured argumentation. The essay jumps between points without smooth transitions, and the overall narrative feels underdeveloped. While the core ideas are present, they are not articulated with sufficient depth or sophistication to convey a truly clear thought process. The conclusion reiterates the main points but lacks a strong, decisive statement.',
#  'analysis_feedback': "The essay touches upon relevant aspects of AI in India, including its potential benefits in sectors like agriculture, healthcare, and education, as well as the challenges related to digital divide, job displacement, and data privacy. However, the analysis lacks depth. The language is overly simplistic, and the points are presented superficially without much elaboration or supporting evidence. For instance, while mentioning 'AI for All', the essay doesn't delve into the specifics of the program or its implementation challenges. Similarly, the discussion on job displacement and privacy is brief and doesn't explore the nuances or potential solutions. The essay would benefit from a more sophisticated vocabulary, a structured approach, and a deeper exploration of the complexities involved in India's AI journey.",
#  'language_feedback': 'The essay demonstrates a basic understanding of Artificial Intelligence (AI) and its potential impact on India. The language used is simple and direct, which makes the core ideas accessible. However, there are significant grammatical errors, awkward phrasing, and a lack of sophisticated vocabulary that detract from the overall quality. For instance, phrases like "Artificial Intel… something (AI)", "India also want become big in this AI thing", "many good", "engine-ear", "farm, doctor place, school and transport", "sick early", "find bad people", "many villager no have phone or internet", "AI and machine do work", "Poor people get more bad", "AI need big big data", "Who take care?", "India still make data rule", "AI do bad", "govern, school, company and normal people", "AI not bad", "talk to other country and learn from them", "use AI good way", "help poor and make better life", "only rich use AI, and poor no get, then big bad thing happen", "many hope and many danger", "go right road", "help all people, not only some", and "world say \'good job India\'" are unidiomatic and grammatically incorrect. The essay would benefit greatly from improved sentence structure, correct verb conjugations, appropriate vocabulary, and more formal language suitable for discussing technology and national development. The ideas presented are relevant but could be expanded upon with more specific examples and a clearer articulation of the challenges and opportunities.',
#  'individual_scores': [4, 4, 4],
#  'overall_feedback': "Here's a summarized feedback based on the provided critiques:\n\n**Overall Summary:**\n\nThe essay demonstrates a foundational understanding of Artificial Intelligence (AI) and its potential impact on India, correctly identifying key strengths like technical talent and government support, as well as challenges such as the digital divide, job displacement, and data privacy. However, the clarity of thought, depth of analysis, and language quality are significantly hindered by simplistic and repetitive phrasing, grammatical errors, awkward sentence structures, and a lack of sophisticated vocabulary. The arguments are underdeveloped, transitions are abrupt, and the analysis remains superficial without sufficient elaboration or supporting evidence. To improve, the essay needs a more structured approach, deeper exploration of complex issues, richer vocabulary, and correction of grammatical inaccuracies to convey a clear, well-analyzed, and professional discussion of AI in India.",
#  'average_score': 4.0}
